# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as pdr
import yfinance as yf
import matplotlib
yf.pdr_override()

# %%
goog=pdr.get_data_yahoo('GOOG',start='2009-3-14',end='2014-4-14')
goog.tail()
goog["Log_Ret"]=np.log(goog["Close"]/goog["Close"].shift(1))
goog["Volatility"]=goog["Log_Ret"].rolling(252).std()
goog["Volatility"]
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2009-03-16         NaN
# 2009-03-17         NaN
# 2009-03-18         NaN
# 2009-03-19         NaN
# 2009-03-20         NaN
#                 ...
# 2014-04-07    0.014058
# 2014-04-08    0.014178
# 2014-04-09    0.014180
# 2014-04-10    0.014441
# 2014-04-11    0.014499
# Name: Volatility, Length: 1279, dtype: float64

# %%
# %matplotlib inline
goog[["Close","Volatility"]].plot(subplots=True,color='blue',figsize=(8,6))
# Out:
# array([<AxesSubplot: xlabel='Date'>, <AxesSubplot: xlabel='Date'>],
#       dtype=object)
